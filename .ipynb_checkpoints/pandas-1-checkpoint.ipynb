# %%
import pandas as pd

# %%
data1 = [{"name":"ashik","age":21,"score":95},{"name":"rahul","age":22,"score":99},{"name":"shiva","age":23,"score":55}]

# %%
df = pd.DataFrame(data1)

# %%
df
# Out:
#     name  age  score
# 0  ashik   21     95
# 1  rahul   22     99
# 2  shiva   23     55

# %%
df["score"]
# Out:
# 0    95
# 1    99
# 2    55
# Name: score, dtype: int64

# %%
df[df["score"]>80]
# Out:
#     name  age  score
# 0  ashik   21     95
# 1  rahul   22     99

# %%
df.loc[0,"name"]
# Out:
# 'ashik'

# %%
df.iloc[0,1]
# Out:
# np.int64(21)
